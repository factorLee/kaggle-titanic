# %% [markdown]
# # Learning-by-Doing
# ## titanic
# ## 1. 데이터 불러오기

# %%
# import pd in the setupfile
train = pd.read_csv('input/train.csv')
test = pd.read_csv('input/test.csv')

# %% [markdown]
# ## 2. 데이터 확인

# %%
train.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
test.tail()
# Out:
#      PassengerId  Pclass                          Name     Sex   Age  SibSp  \
# 413         1305       3            Spector, Mr. Woolf    male   NaN      0
# 414         1306       1  Oliva y Ocana, Dona. Fermina  female  39.0      0
# 415         1307       3  Saether, Mr. Simon Sivertsen    male  38.5      0
# 416         1308       3           Ware, Mr. Frederick    male   NaN      0
# 417         1309       3      Peter, Master. Michael J    male   NaN      1
#
#      Parch              Ticket      Fare Cabin Embarked
# 413      0           A.5. 3236    8.0500   NaN        S
# 414      0            PC 17758  108.9000  C105        C
# 415      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416      0              359309    8.0500   NaN        S
# 417      1                2668   22.3583   NaN        C

# %% [markdown]
# ## 2.1 데이터 크기 확인

# %%
train.shape # 891개의 승객정보, 12개의 feature 정보
# Out:
# (891, 12)

# %%
test.shape # 418 명의 승객정보를 바탕으로 Survived를 판단
# Out:
# (418, 11)

# %% [markdown]
# ### 2.2.1 데이터 유실정보 확인 ```info()```

# %%
train.info() # Cabin 204, Age 714 유실정보 확인
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
test.info() # train data set과 비슷한 비율 확인
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %% [markdown]
# ### 2.2.2 유실정보 확인 ```isnull()```

# %%
# isnull
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
test.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %% [markdown]
# ### import python lib for visualization

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()

# %% [markdown]
# ## 3. 직관적 Feature 분석

# %%
# 한개의 feature에 따라 살았는지 죽었는지
def bar_chart(feature):
    survived = train[train['Survived']==1][feature].value_counts()
    dead = train[train['Survived']==0][feature].value_counts()
    df = pd.DataFrame([survived, dead])
    df.index = ['Survived', 'Dead']
    df.plot(kind='bar', stacked=True, figsize=(10,5))

# %%
bar_chart('Sex')

# %%
bar_chart('Pclass')

# %%
bar_chart('SibSp')

# %%
bar_chart('Parch')

# %%
bar_chart('Embarked')

# %% [markdown]
# ## 4. Feature Engineering (data columns)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ## 4.1 Feature vector
# ### Name

# %%
# 이름에서 타이틀 빼내오기 (miss, mr...)
train_test_data = [train, test] # 뭉처서 변형을 한번에 시킴

for dataset in train_test_data:
    dataset['Title'] = dataset['Name'].str.extract('([A-Za-z]+)\.', expand=False)

# %%
train['Title'].value_counts()
# Out:
# Mr          517
# Miss        182
# Mrs         125
# Master       40
# Dr            7
# Rev           6
# Major         2
# Col           2
# Mlle          2
# Ms            1
# Jonkheer      1
# Don           1
# Lady          1
# Sir           1
# Capt          1
# Countess      1
# Mme           1
# Name: Title, dtype: int64

# %%
test['Title'].value_counts()
# Out:
# Mr        240
# Miss       78
# Mrs        72
# Master     21
# Col         2
# Rev         2
# Ms          1
# Dona        1
# Dr          1
# Name: Title, dtype: int64

# %%
# maping
title_mapping = {"Mr": 0, "Miss": 1, "Mrs": 2, 
                 "Master": 3, "Dr": 3, "Rev": 3, "Col": 3, "Major": 3, "Mlle": 3, "Countess": 3,
                 "Ms": 3, "Lady": 3, "JonKheer": 3, "Don": 3, "Dona": 3, "Mme": 3, "Capt": 3, "Sir": 3}

for dataset in train_test_data:
    dataset['Title'] = dataset['Title'].map(title_mapping)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Title
# 0      0         A/5 21171   7.2500   NaN        S    0.0
# 1      0          PC 17599  71.2833   C85        C    2.0
# 2      0  STON/O2. 3101282   7.9250   NaN        S    1.0
# 3      0            113803  53.1000  C123        S    2.0
# ...

# %%
bar_chart('Title')
# 남자인 Mr가 상대적으로 더 많이 죽었다라는 데이터를 얻었다.
# 이제 Name는 필요가 없으므로 삭제

# %%
# delete unnecessary feature from dataset
train.drop('Name', axis=1, inplace=True)
test.drop('Name', axis=1, inplace=True)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0            1         0       3    male  22.0      1      0
# 1            2         1       1  female  38.0      1      0
# 2            3         1       3  female  26.0      0      0
# 3            4         1       1  female  35.0      1      0
# 4            5         0       3    male  35.0      0      0
#
#              Ticket     Fare Cabin Embarked  Title
# 0         A/5 21171   7.2500   NaN        S    0.0
# 1          PC 17599  71.2833   C85        C    2.0
# 2  STON/O2. 3101282   7.9250   NaN        S    1.0
# 3            113803  53.1000  C123        S    2.0
# 4            373450   8.0500   NaN        S    0.0

# %%
test.head()
# Out:
#    PassengerId  Pclass     Sex   Age  SibSp  Parch   Ticket     Fare Cabin  \
# 0          892       3    male  34.5      0      0   330911   7.8292   NaN
# 1          893       3  female  47.0      1      0   363272   7.0000   NaN
# 2          894       2    male  62.0      0      0   240276   9.6875   NaN
# 3          895       3    male  27.0      0      0   315154   8.6625   NaN
# 4          896       3  female  22.0      1      1  3101298  12.2875   NaN
#
#   Embarked  Title
# 0        Q      0
# 1        S      2
# 2        Q      0
# 3        S      0
# 4        S      2

# %% [markdown]
# ## 4.3 Sex
# ### male: 0, female: 1

# %%
sex_mapping = {"male": 0, "female": 1}

for dataset in train_test_data:
    dataset['Sex'] = dataset['Sex'].map(sex_mapping)

# %%
bar_chart('Sex')

# %% [markdown]
# ## 4.4 Age
# - Missing infomation
#     - e.g. mean, median ... 값 넣기

# %%
train.head(100)
# Out:
#     PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch            Ticket  \
# 0             1         0       3    0  22.0      1      0         A/5 21171
# 1             2         1       1    1  38.0      1      0          PC 17599
# 2             3         1       3    1  26.0      0      0  STON/O2. 3101282
# 3             4         1       1    1  35.0      1      0            113803
# 4             5         0       3    0  35.0      0      0            373450
# ..          ...       ...     ...  ...   ...    ...    ...               ...
# 95           96         0       3    0   NaN      0      0            374910
# 96           97         0       1    0  71.0      0      0          PC 17754
# 97           98         1       1    0  23.0      0      1          PC 17759
# 98           99         1       2    1  34.0      0      1            231919
# 99          100         0       2    0  34.0      1      0            244367
#
#        Fare    Cabin Embarked  Title
# ...

# %%
# fill missing age with median age for each title (Mr, Mrs, Miss, Others)
train["Age"].fillna(train.groupby("Title")["Age"].transform("median"), inplace=True)    
test["Age"].fillna(train.groupby("Title")["Age"].transform("median"), inplace=True)    
# == Age가 null일 경우 각 Title 별로 그 Age의 median(중앙값)을 써라

# %%
facet = sns.FacetGrid(train, hue="Survived", aspect=4)
facet.map(sns.kdeplot, 'Age', shade=True)
facet.set(xlim=(0, train['Age'].max()))
facet.add_legend()

plt.show()

# %%
facet = sns.FacetGrid(train, hue="Survived", aspect=4)
facet.map(sns.kdeplot, 'Age', shade=True)
facet.set(xlim=(0, train['Age'].max()))
facet.add_legend()
plt.xlim(0, 20)
# Out:
# (0.0, 20.0)

# %%
facet = sns.FacetGrid(train, hue="Survived", aspect=4)
facet.map(sns.kdeplot, 'Age', shade=True)
facet.set(xlim=(0, train['Age'].max()))
facet.add_legend()
plt.xlim(20, 30)
# Out:
# (20.0, 30.0)

# %%
facet = sns.FacetGrid(train, hue="Survived", aspect=4)
facet.map(sns.kdeplot, 'Age', shade=True)
facet.set(xlim=(0, train['Age'].max()))
facet.add_legend()
plt.xlim(30, 40)
# Out:
# (30.0, 40.0)

# %%
facet = sns.FacetGrid(train, hue="Survived", aspect=4)
facet.map(sns.kdeplot, 'Age', shade=True)
facet.set(xlim=(0, train['Age'].max()))
facet.add_legend()
plt.xlim(40, 50)
# Out:
# (40.0, 50.0)

# %%
facet = sns.FacetGrid(train, hue="Survived", aspect=4)
facet.map(sns.kdeplot, 'Age', shade=True)
facet.set(xlim=(0, train['Age'].max()))
facet.add_legend()
plt.xlim(50, 80)
# Out:
# (50.0, 80.0)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Sex          891 non-null    int64
#  4   Age          891 non-null    float64
#  5   SibSp        891 non-null    int64
#  6   Parch        891 non-null    int64
#  7   Ticket       891 non-null    object
#  8   Fare         891 non-null    float64
#  9   Cabin        204 non-null    object
#  10  Embarked     889 non-null    object
#  11  Title        890 non-null    float64
# dtypes: float64(3), int64(6), object(3)
# memory usage: 83.7+ KB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Sex          418 non-null    int64
#  3   Age          418 non-null    float64
#  4   SibSp        418 non-null    int64
#  5   Parch        418 non-null    int64
#  6   Ticket       418 non-null    object
#  7   Fare         417 non-null    float64
#  8   Cabin        91 non-null     object
#  9   Embarked     418 non-null    object
#  10  Title        418 non-null    int64
# dtypes: float64(2), int64(6), object(3)
# memory usage: 36.0+ KB

# %% [markdown]
# ## 4.4.2 Binning

# %%
# Categorical classification
for dataset in train_test_data:
    dataset.loc[dataset['Age'] <= 16, 'Age'] = 0
    dataset.loc[(dataset['Age'] > 16) & (dataset['Age'] <= 26), 'Age'] = 1
    dataset.loc[(dataset['Age'] > 26) & (dataset['Age'] <= 36), 'Age'] = 2
    dataset.loc[(dataset['Age'] > 36) & (dataset['Age'] <= 62), 'Age'] = 3
    dataset.loc[dataset['Age'] > 62, 'Age'] = 4

# %%
# Age를 숫자 Categorical로 표현 확인
train.tail()
# Out:
#      PassengerId  Survived  Pclass  Sex  Age  SibSp  Parch      Ticket   Fare  \
# 886          887         0       2    0  2.0      0      0      211536  13.00
# 887          888         1       1    1  1.0      0      0      112053  30.00
# 888          889         0       3    1  1.0      1      2  W./C. 6607  23.45
# 889          890         1       1    0  1.0      0      0      111369  30.00
# 890          891         0       3    0  2.0      0      0      370376   7.75
#
#     Cabin Embarked  Title
# 886   NaN        S    3.0
# 887   B42        S    1.0
# 888   NaN        S    1.0
# 889  C148        C    0.0
# 890   NaN        Q    0.0

# %%
bar_chart('Age')

# %% [markdown]
# ## 4.5 Embarked (탑승 위치)
# ### 4.5.1 filling missing values

# %%
Pclass1 = train[train["Pclass"]==1]['Embarked'].value_counts()
Pclass2 = train[train["Pclass"]==2]['Embarked'].value_counts()
Pclass3 = train[train["Pclass"]==3]['Embarked'].value_counts()
df = pd.DataFrame([Pclass1, Pclass2, Pclass3])
df.index = ['1st class', '2nd class', '3rd class']
df.plot(kind='bar', stacked=True, figsize=(10,5))
print(df)
# S에서 탑승한 사람이 절반 이상인 것을 알 수 있다. => Embarked 정보가 없으면 S로 대체가 가능하다.
# Q에서 탑승한 사람들은 1등급 자리에는 거의 없다.
# Out:
#              S   C   Q
# 1st class  127  85   2
# 2nd class  164  17   3
# 3rd class  353  66  72

# %%
# Emarked에 정보가 없으면 S를 집어 넣어라
for dataset in train_test_data:
    dataset['Embarked'] = dataset['Embarked'].fillna('S')

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  Sex  Age  SibSp  Parch            Ticket  \
# 0            1         0       3    0  1.0      1      0         A/5 21171
# 1            2         1       1    1  3.0      1      0          PC 17599
# 2            3         1       3    1  1.0      0      0  STON/O2. 3101282
# 3            4         1       1    1  2.0      1      0            113803
# 4            5         0       3    0  2.0      0      0            373450
#
#       Fare Cabin Embarked  Title
# 0   7.2500   NaN        S    0.0
# 1  71.2833   C85        C    2.0
# 2   7.9250   NaN        S    1.0
# 3  53.1000  C123        S    2.0
# 4   8.0500   NaN        S    0.0

# %%
train.info() # Embarked 891
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Sex          891 non-null    int64
#  4   Age          891 non-null    float64
#  5   SibSp        891 non-null    int64
#  6   Parch        891 non-null    int64
#  7   Ticket       891 non-null    object
#  8   Fare         891 non-null    float64
#  9   Cabin        204 non-null    object
#  10  Embarked     891 non-null    object
#  11  Title        890 non-null    float64
# dtypes: float64(3), int64(6), object(3)
# memory usage: 83.7+ KB

# %%
# Text => number
embarked_mapping = {"S": 0, "C": 1, "Q": 2}
for dataset in train_test_data:
    dataset['Embarked'] = dataset['Embarked'].map(embarked_mapping)

# %% [markdown]
# ## 4.6 Fare

# %%
# fill missing Fare with median fare for each Pclass
train["Fare"].fillna(train.groupby("Pclass")["Fare"].transform("median"), inplace=True)
test["Fare"].fillna(test.groupby("Pclass")["Fare"].transform("median"), inplace=True)

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Sex          418 non-null    int64
#  3   Age          418 non-null    float64
#  4   SibSp        418 non-null    int64
#  5   Parch        418 non-null    int64
#  6   Ticket       418 non-null    object
#  7   Fare         418 non-null    float64
#  8   Cabin        91 non-null     object
#  9   Embarked     418 non-null    int64
#  10  Title        418 non-null    int64
# dtypes: float64(2), int64(7), object(2)
# memory usage: 36.0+ KB

# %%
facet = sns.FacetGrid(train, hue="Survived", aspect=4)
facet.map(sns.kdeplot, 'Fare', shade=True)
facet.set(xlim=(0, train['Fare'].max()))
facet.add_legend()

plt.show()

# %%
facet = sns.FacetGrid(train, hue="Survived", aspect=4)
facet.map(sns.kdeplot, 'Fare', shade=True)
facet.set(xlim=(0, train['Fare'].max()))
facet.add_legend()
plt.xlim(0, 20)
# Out:
# (0.0, 20.0)

# %%
facet = sns.FacetGrid(train, hue="Survived", aspect=4)
facet.map(sns.kdeplot, 'Fare', shade=True)
facet.set(xlim=(0, train['Fare'].max()))
facet.add_legend()
plt.xlim(0, 30)
# Out:
# (0.0, 30.0)

# %%
facet = sns.FacetGrid(train, hue="Survived", aspect=4)
facet.map(sns.kdeplot, 'Fare', shade=True)
facet.set(xlim=(0, train['Fare'].max()))
facet.add_legend()
plt.xlim(0)
# Out:
# (0.0, 512.3292)

# %%
# Binning
for dataset in train_test_data:
    dataset.loc[dataset['Fare'] <= 17, 'Fare'] = 0
    dataset.loc[(dataset['Fare'] > 17) & (dataset['Fare'] <= 30), 'Fare'] = 1
    dataset.loc[(dataset['Fare'] > 30) & (dataset['Fare'] <= 100), 'Fare'] = 2
    dataset.loc[dataset['Fare'] > 100, 'Fare'] = 3

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  Sex  Age  SibSp  Parch            Ticket  \
# 0            1         0       3    0  1.0      1      0         A/5 21171
# 1            2         1       1    1  3.0      1      0          PC 17599
# 2            3         1       3    1  1.0      0      0  STON/O2. 3101282
# 3            4         1       1    1  2.0      1      0            113803
# 4            5         0       3    0  2.0      0      0            373450
#
#    Fare Cabin  Embarked  Title
# 0   0.0   NaN         0    0.0
# 1   2.0   C85         1    2.0
# 2   0.0   NaN         0    1.0
# 3   2.0  C123         0    2.0
# 4   0.0   NaN         0    0.0

# %% [markdown]
# ## 4.7 Cabin

# %%
train.Cabin.value_counts()
# Out:
# G6             4
# C23 C25 C27    4
# B96 B98        4
# E101           3
# F33            3
#               ..
# C101           1
# E36            1
# B94            1
# D7             1
# E17            1
# Name: Cabin, Length: 147, dtype: int64

# %%
for dataset in train_test_data:
    dataset['Cabin'] = dataset['Cabin'].str[:1]

# %%
Pclass1 = train[train['Pclass']==1]['Cabin'].value_counts()
Pclass2 = train[train['Pclass']==2]['Cabin'].value_counts()
Pclass2 = train[train['Pclass']==3]['Cabin'].value_counts()
df = pd.DataFrame([Pclass1, Pclass2, Pclass3])
df.index = ['1st class', '2nd class', '3rd class']
df.plot(kind='bar', stacked=True, figsize=(10,5))
print(df)
# Out:
#               C     B     D     E     A    T    F    G      S     Q
# 1st class  59.0  47.0  29.0  25.0  15.0  1.0  NaN  NaN    NaN   NaN
# 2nd class   NaN   NaN   NaN   3.0   NaN  NaN  5.0  4.0    NaN   NaN
# 3rd class  66.0   NaN   NaN   NaN   NaN  NaN  NaN  NaN  353.0  72.0

# %%
# feature mapping & scaling
cabin_mapping = {"A":0, "B":0.4, "C":0.8, "D":1.2, "E":1.6, "F":2, "G":2.4, "T":2.8}

for dataset in train_test_data:
    dataset['Cabin'] = dataset['Cabin'].map(cabin_mapping)

# %%
train["Cabin"].fillna(train.groupby("Pclass")["Cabin"].transform("median"), inplace=True)
test["Cabin"].fillna(test.groupby("Pclass")["Cabin"].transform("median"), inplace=True)

# %% [markdown]
# ## 4.8 FamilySize

# %%
train["FamilySize"] = train["SibSp"] + train["Parch"] + 1
test["FamilySize"] = test["SibSp"] + test["Parch"] + 1

# %%
facet = sns.FacetGrid(train, hue="Survived", aspect=4)
facet.map(sns.kdeplot, 'FamilySize', shade=True)
facet.set(xlim=(0, train['FamilySize'].max()))
facet.add_legend()
plt.xlim(0)
# Out:
# (0.0, 11.0)

# %%
family_mapping = {1:0, 2:0.4, 3:0.8, 4:1.2, 5:1.6, 6:2, 7:2.4, 8:2.8, 9:3.2, 10:3.6, 11:4}

for dataset in train_test_data:
    dataset["FamilySize"] = dataset['FamilySize'].map(family_mapping)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  Sex  Age  SibSp  Parch            Ticket  \
# 0            1         0       3    0  1.0      1      0         A/5 21171
# 1            2         1       1    1  3.0      1      0          PC 17599
# 2            3         1       3    1  1.0      0      0  STON/O2. 3101282
# 3            4         1       1    1  2.0      1      0            113803
# 4            5         0       3    0  2.0      0      0            373450
#
#    Fare  Cabin  Embarked  Title  FamilySize
# 0   0.0    2.0         0    0.0         0.4
# 1   2.0    0.8         1    2.0         0.4
# 2   0.0    2.0         0    1.0         0.0
# 3   2.0    0.8         0    2.0         0.4
# 4   0.0    2.0         0    0.0         0.0

# %%
features_drop = ['Ticket', 'SibSp', 'Parch']
train = train.drop(features_drop, axis=1)
test = test.drop(features_drop, axis=1)
train = train.drop(['PassengerId'], axis=1)

# %%
train_data = train.drop('Survived', axis=1)
target = train['Survived']

train_data.shape, target.shape
# Out:
# ((891, 8), (891,))

# %%
train_data.head(10)
# Out:
#    Pclass  Sex  Age  Fare  Cabin  Embarked  Title  FamilySize
# 0       3    0  1.0   0.0    2.0         0    0.0         0.4
# 1       1    1  3.0   2.0    0.8         1    2.0         0.4
# 2       3    1  1.0   0.0    2.0         0    1.0         0.0
# 3       1    1  2.0   2.0    0.8         0    2.0         0.4
# 4       3    0  2.0   0.0    2.0         0    0.0         0.0
# 5       3    0  2.0   0.0    2.0         2    0.0         0.0
# 6       1    0  3.0   2.0    1.6         0    0.0         0.0
# 7       3    0  0.0   1.0    2.0         0    3.0         1.6
# 8       3    1  2.0   0.0    2.0         0    2.0         0.8
# 9       2    1  0.0   2.0    1.8         1    2.0         0.4

# %% [markdown]
# ## 5. Modeling

# %%
# Importing Classifier Modules
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVM

import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-91-7d4d6ce2723e> in <module>
#       4 from sklearn.ensemble import RandomForestClassifier
#       5 from sklearn.naive_bayes import GaussianNB
# ----> 6 from sklearn.svm import SVM
#       7
#       8
#
# ImportError: cannot import name 'SVM' from 'sklearn.svm' (/usr/local/lib/python3.9/site-packages/sklearn/svm/__init__.py)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Survived    891 non-null    int64
#  1   Pclass      891 non-null    int64
#  2   Sex         891 non-null    int64
#  3   Age         891 non-null    float64
#  4   Fare        891 non-null    float64
#  5   Cabin       891 non-null    float64
#  6   Embarked    891 non-null    int64
#  7   Title       890 non-null    float64
#  8   FamilySize  891 non-null    float64
# dtypes: float64(5), int64(4)
# memory usage: 62.8 KB

# %% [markdown]
# ## 6.1 Cross Validation (K-fold)

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
k_fold = KFold(n_splits=10, shuffle=True, random_state=0)

# %% [markdown]
# ## 6.1.1 kNN

# %%
clf = KNeighborsClassifier(n_neighbors = 13)
scoring = 'accuracy'
score = cross_val_score(clf, train_data, target, cv=k_fold, n_jobs=1, scoring=scoring)
print(score)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-78-7a42836802e0> in <module>
# ----> 1 clf = KNeighborsClassifier(n_neighbors = 13)
#       2 scoring = 'accuracy'
#       3 score = cross_val_score(clf, train_data, target, cv=k_fold, n_jobs=1, scoring=scoring)
#       4 print(score)
#
# NameError: name 'KNeighborsClassifier' is not defined
